# %%
import pandas as pd

results = pd.DataFrame({
    'Model': ['Naive Bayes','KNN','Decision Tree','Random Forest','SVM','Logistic Regression','ANN','XGBoost'],
    'Accuracy':[0.77,0.69,0.74,0.79,0.76,0.77,0.77,0.75]
})

results.sort_values(by='Accuracy', ascending=False)
# Out:
#                  Model  Accuracy
# 3        Random Forest      0.79
# 0          Naive Bayes      0.77
# 6                  ANN      0.77
# 5  Logistic Regression      0.77
# 4                  SVM      0.76
# 7              XGBoost      0.75
# 2        Decision Tree      0.74
# 1                  KNN      0.69

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(results['Model'], results['Accuracy'])
plt.xticks(rotation=45)
plt.title("Model Comparison")
plt.show()
